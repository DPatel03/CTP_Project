# %%
import pandas as pd
import numpy as np
import geopandas
import geoplot
from shapely.geometry import Point, Polygon
import matplotlib.pyplot as plt

import seaborn as sns

# %%
ds = pd.read_csv('sleep_data_sampled.csv')
# i used Sleep_Data_Sampled for this page
ds.head(100)
# Out:
#     Person ID  Gender  Age         Occupation  Sleep Duration  \
# 0           1    Male   35             Doctor            6.65
# 1           2    Male   42            Teacher            6.90
# 2           3    Male   34  Software Engineer            6.95
# 3           4    Male   32             Doctor            6.90
# 4           5    Male   37             Lawyer            6.85
# ..        ...     ...  ...                ...             ...
# 95         96    Male   36             Lawyer            7.70
# 96         97  Female   42           Engineer            8.00
# 97         98    Male   36             Lawyer            7.45
# 98         99  Female   45         Accountant            7.85
# 99        100    Male   41           Engineer            7.45
#
#     Quality of Sleep  Physical Activity Level  Stress Level   BMI Category  \
# 0                  7                       50             7  Normal Weight
# ...

# %%
ds.describe()
# Out:
#           Person ID           Age  Sleep Duration  Quality of Sleep  \
# count  15000.000000  15000.000000    15000.000000      15000.000000
# mean    7500.500000     44.130667        6.997327          7.131267
# std     4330.271354      6.840091        0.615187          1.053111
# min        1.000000     27.000000        5.800000          4.000000
# 25%     3750.750000     40.000000        6.500000          6.000000
# 50%     7500.500000     44.000000        7.000000          7.000000
# 75%    11250.250000     48.000000        7.450000          8.000000
# max    15000.000000     59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level    Heart Rate   Daily Steps
# count             15000.000000  15000.000000  15000.000000  15000.000000
# mean                 59.925000      5.654800     70.857533   6795.080000
# std                  16.814374      1.393568      3.614836   1329.706484
# ...

# %% [markdown]
# ### Datasets info

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                15000 non-null  int64
#  1   Gender                   15000 non-null  object
#  2   Age                      15000 non-null  int64
#  3   Occupation               15000 non-null  object
#  4   Sleep Duration           15000 non-null  float64
#  5   Quality of Sleep         15000 non-null  int64
#  6   Physical Activity Level  15000 non-null  int64
#  7   Stress Level             15000 non-null  int64
#  8   BMI Category             15000 non-null  object
#  9   Blood Pressure           15000 non-null  object
#  10  Heart Rate               15000 non-null  int64
#  11  Daily Steps              15000 non-null  int64
#  12  Sleep Disorder           15000 non-null  object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 1.5+ MB

# %% [markdown]
# ### Remove Unwanted Columns

# %%
ds_new = ds.drop(columns=["Person ID", "Blood Pressure" ])
ds_new.to_csv("demo.csv", index=False)

# %%
ds_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Gender                   15000 non-null  object
#  1   Age                      15000 non-null  int64
#  2   Occupation               15000 non-null  object
#  3   Sleep Duration           15000 non-null  float64
#  4   Quality of Sleep         15000 non-null  int64
#  5   Physical Activity Level  15000 non-null  int64
#  6   Stress Level             15000 non-null  int64
#  7   BMI Category             15000 non-null  object
#  8   Heart Rate               15000 non-null  int64
#  9   Daily Steps              15000 non-null  int64
#  10  Sleep Disorder           15000 non-null  object
# dtypes: float64(1), int64(6), object(4)
# memory usage: 1.3+ MB

# %% [markdown]
# ### Now Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
ds_new["Age"] = pd.DataFrame(le.fit_transform(ds_new["Age"]))
ds_new["Sleep Duration"] = pd.DataFrame(le.fit_transform(ds_new["Sleep Duration"]))
ds_new["Quality of Sleep"] = pd.DataFrame(le.fit_transform(ds_new["Quality of Sleep"]))
ds_new["Physical Activity Level"] = pd.DataFrame(le.fit_transform(ds_new["Physical Activity Level"]))
ds_new["Stress Level"] = pd.DataFrame(le.fit_transform(ds_new["Stress Level"]))
ds_new["Daily Steps"] = pd.DataFrame(le.fit_transform(ds_new["Daily Steps"]))
ds_new["Occupation"] = pd.DataFrame(le.fit_transform(ds_new["Occupation"]))
ds_new["Gender"] = pd.DataFrame(le.fit_transform(ds_new["Gender"]))

# %%
ds_new.head()
# Out:
#    Gender  Age  Occupation  Sleep Duration  Quality of Sleep  \
# 0       1    8           1              17                 3
# 1       1   15          10              22                 4
# 2       1    7           9              23                 3
# 3       1    5           1              22                 2
# 4       1   10           3              21                 3
#
#    Physical Activity Level  Stress Level   BMI Category  Heart Rate  \
# 0                       15             4  Normal Weight          71
# 1                       17             1         Normal          66
# 2                       26             3     Overweight          74
# 3                       17             4         Normal          71
# 4                       22             3         Normal          71
#
#    Daily Steps Sleep Disorder
# 0           64        Healthy
# 1           62        Healthy
# 2           47        Healthy
# 3           54        Healthy
# 4           54        Healthy

# %%
ds_new["Quality of Sleep"].unique()

# %%
from sklearn.model_selection import train_test_split

# %%
x = ds_new.iloc[:,:-1]
y = ds_new["Quality of Sleep"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# ### Training Model

# %%
from sklearn.linear_model import LogisticRegression

# %%
# Out:
# Training Accuracy: 100.00%
# Testing Accuracy: 0.00%

# %%
lr.score(x_train, y_train)*100, lr.score(x_test, y_test)*100
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/0r/2_22wh2s1d7dyh4jrtwdyjq40000gn/T/ipykernel_2510/3348580051.py in ?()
# ----> 1 lr.score(x_train, y_train)*100, lr.score(x_test, y_test)*100
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/base.py in ?(self, X, y, sample_weight)
#     760             Mean accuracy of ``self.predict(X)`` w.r.t. `y`.
#     761         """
#     762         from .metrics import accuracy_score
#     763
# --> 764         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/linear_model/_base.py in ?(self, X)
#     378         y_pred : ndarray of shape (n_samples,)
#     379             Vector containing the class labels for each sample.
#     380         """
# ...
